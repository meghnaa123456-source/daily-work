# %%
fruits=["apple","banana","cherry","kiwi","mango"]
if "l" in "apple":print("yes")
# Out:
# yes

# %%
fruits=["apple","banana","cherry","kiwi","mango"]
if "l" in "apple":
    print("yes")
else:
    print("no")
# Out:
# yes

# %%
print("yes")if "l" in "apple" else print("no")
# Out:
# yes

# %%
a=10
b=20
c=15
print("a>")if a>b and a>c else print("b>")if b>a and b>c else print("c>")
# Out:
# b>

# %%
fruits=["apple","banana","cherry","kiwi","mango"]
y=[i for i in fruits if "a" in i]

# %%
y
# Out:
# ['apple', 'banana', 'mango']

# %%
n=[23,45,22,45,23,46]
odd=[i for i in n if i%2!=0]

# %%
odd
# Out:
# [23, 45, 45, 23]

# %%
fruits=["app","banana","cherry","kiwi","app","mango"]
f=["apple" if i=="app" else i for i in fruits]

# %%
f
# Out:
# ['apple', 'banana', 'cherry', 'kiwi', 'apple', 'mango']

# %%
salary=[12,34,45,234,435,23,453]
r=["high salary" if i >100 else "low salary" for i in salary]

# %%
r
# Out:
# ['low salary',
#  'low salary',
#  'low salary',
#  'high salary',
#  'high salary',
#  'low salary',
#  'high salary']

# %%
n=[12,34,45,234,435,23,453]
n.sort()

# %%
n
# Out:
# [12, 23, 34, 45, 234, 435, 453]

# %%
n=[12,34,45,234,435,23,453]
n.sort(reverse=True)

# %%
n
# Out:
# [453, 435, 234, 45, 34, 23, 12]

# %%
a=[23,34,45]
b=[34,45,34]
a+b
# Out:
# [23, 34, 45, 34, 45, 34]

# %%
a=[23,34,44]
for i in b:
    a.append(i)

# %%
a
# Out:
# [23, 34, 44, 34, 45, 34]

# %%
x=["apple","banana","cherry","kiwi","apple","mango"]
def lastchar(n):
    return len(n)
x.sort(key=lastchar)

# %%
x
# Out:
# ['kiwi', 'apple', 'apple', 'mango', 'banana', 'cherry']

# %%
x=["apple","banana","cherry","kiwi","apple","mango"]
def lastchar(n):
    return n[-1]
x.sort(key=lastchar)

# %%
x
# Out:
# ['banana', 'apple', 'apple', 'kiwi', 'mango', 'cherry']

# %%
num=[12,34,45,23,234,431,23,453]
def lastchar(n):
    n=str(n)
    return n[-1]
num.sort(key=lastchar)

# %%
num
# Out:
# [431, 12, 23, 23, 453, 34, 234, 45]
