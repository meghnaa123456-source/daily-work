# %%
x=["apple","banana"]
x.append("mango")

# %%
x
# Out:
# ['apple', 'banana', 'mango']

# %%
x.insert(2,"kiwi")

# %%
x
# Out:
# ['apple', 'banana', 'kiwi', 'mango']

# %%
x=["apple","banana"]
y=["papaya","black"]
x.extend(y)

# %%
x
# Out:
# ['apple', 'banana', 'papaya', 'black']

# %%
x=["apple","banana"]
x.remove('banana')

# %%
x
# Out:
# ['apple']

# %%
x=["apple","banana","kiwi"]
x.pop(1)
# Out:
# 'banana'

# %%
x
# Out:
# ['apple', 'kiwi']

# %%
x=["apple","banana"]
x.pop()
# Out:
# 'banana'

# %%
x
# Out:
# ['apple']

# %%
x=["apple","banana"]
del x[1]

# %%
x
# Out:
# ['apple']

# %%
x=["apple","banana"]
x.clear
# Out:
# <function list.clear()>

# %%
x
# Out:
# ['apple', 'banana']

# %%
x="hello"
x .upper()
# Out:
# 'HELLO'

# %%
x="hello"
x.lower()
# Out:
# 'hello'

# %%
x="  hello world"
x.strip()
# Out:
# 'hello  world'

# %%
x="  hello world  "
x.lstrip()
# Out:
# 'hello world  '

# %%
x="  hello world  "
x.rstrip()
# Out:
# '  hello world'

# %%
x="  hello world"
x.split(" ")
# Out:
# ['', '', 'hello', 'world']

# %%
fullname="meghna n"
fullname.split(" ")
# Out:
# ['meghna', 'n']

# %%
[fname,lname]=fullname.split(" ")

# %%
fname
# Out:
# 'meghna'

# %%
lname
# Out:
# 'n'

# %%
name="meghna"
age=21

# %%
name="meghna"
age=21
x=f"my name is meghna and my age is {age}"

# %%
x
# Out:
# 'my name is meghna and my age is 21'

# %%
name="meghna"
salary=50000.1245
"my name is meghna and my salary is"

# %%
print(f"name is {name} salary is {salary:.1f}")
# Out:
# name is meghna n salary is 50000.1

# %%
name="meghna"
name.replace("gh","a")
# Out:
# 'meana'

# %%
name="meghna n"
name.replace("na","gh")
# Out:
# 'meghgh n'

# %%
x='hello my student\' s are'

# %%
x
# Out:
# "hello my student' s are"

# %%
x='hello my student\\ s are'

# %%
x
# Out:
# 'hello my student\\ s are'

# %%
x="hello\nmy students are"

# %%
print(x)
# Out:
# hello
# my students are

# %%
x='hello\r my student s are'

# %%
print(x)
# Out:
#  my student s are

# %%
x='hello\t my students are'

# %%
print(x)
# Out:
# hello	 my students are
